# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_Ciencia_de_Dados/blob/main/Teste_desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

df_cases_risk = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/blood_test2_answers_short.csv')
df_cases_risk['Risk']

diretorio = '/content/drive/MyDrive/IMT_MiniDesafio_1'
arquivos = os.listdir(diretorio)

for arquivo in arquivos:
    if arquivo.endswith('.csv'):
      try:
        caminho_arquivo = os.path.join(diretorio, arquivo)
        df_cases = pd.read_csv(caminho_arquivo)
        print(arquivo)
        print(sum(df_cases['Risk'] == df_cases_risk['Risk']) / len(df_cases))
      except:
        continue
# Out:
# blood_test1_g1.csv
# 0.5333333333333333
# blood_test2_g1.csv
# 0.5333333333333333
# blood_test1_g5.csv
# blood_test2_g5.csv
# blood_test2_g4.csv
# blood_test1_g4.csv
# blood_test1_g2.csv
# blood_test_g14.csv
# blood_test2_g2.csv
# blood_test1_g3.csv
# 0.0
# blood_test1_g12.csv
# 0.0
# blood_test2_g3.csv
# blood_test2_g12.csv
# blood_test1_g6.csv
# 0.0
# blood_test2_g6.csv
# 0.0
# blood_test1_g9.csv
# blood_test2_g9.csv
# blood_test1_g11.csv
# blood_test2_g11.csv
# blood_test1_g7.csv
# 0.43333333333333335
# blood_test2_g7.csv
# 0.4
# blood_test_2_g10.csv
# 0.0
# blood_test_1_g10.csv
# 0.0

# %%
arquivo = 'blood_test1_g5.csv'

caminho_arquivo = os.path.join(diretorio, arquivo)
df_cases = pd.read_csv(caminho_arquivo)

df_cases.head()
# Out:
#    Gluconise  Adrino_posina  Gamma_R  Nitro_K      H278  Plate  Factor_risk  \
# 0  1081.0579              0        5     2.90   3976.95      1            4
# 1  1071.9962              0        3     2.52    246.64      3            2
# 2   804.3828              3        5     5.60  31006.83      3            8
# 3  1175.8583              2       10     3.13   6354.17      3            5
# 4   739.4469              2        6     3.51  10114.04      2            6
#
#    norm_gamma_type  Blood_type  Blood_Rh  y_pred
# 0                0           0         0       1
# 1                0           3         0       1
# 2                1           2         1       1
# 3                1           2         0       1
# 4                1           3         0       1
