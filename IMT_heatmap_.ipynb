# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/IMT_Ciencia_de_Dados/blob/main/IMT_heatmap_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.random.sample(100)
y = x**5 + 2*x + 1 + 0.1* np.random.sample(len(x))

z = np.polyfit(x,y, 5)
p = np.poly1d(z)

plt.scatter(x,y)
plt.plot(np.sort(x),p(np.sort(x)),color='r')

z = np.polyfit(x,y, 1)
p = np.poly1d(z)
plt.plot(np.sort(x),p(np.sort(x)))

plt.show()

# %%
x = np.random.sample(100)
y = x**5 + 2*x + 1 + 0.1* np.random.sample(len(x))

sns.regplot(x=x,y=y)

plt.show()

# %%
data = np.identity(5)
sns.heatmap(data)

plt.show()

# %%
z , w = np.random.sample(100), np.random.sample(100)

data = pd.DataFrame(np.array([x,y,z,w]).T)
data.head()
# Out:
#           0         1         2         3
# 0  0.618422  2.395192  0.897515  0.522080
# 1  0.577640  2.971791  0.530193  0.580093
# 2  0.407564  2.251895  0.669257  0.229591
# 3  0.139766  1.295075  0.161066  0.167300
# 4  0.764699  2.813063  0.483666  0.484807

# %%
sns.pairplot(data) 

plt.show()

# %%
sns.heatmap(data.corr())

plt.show()
